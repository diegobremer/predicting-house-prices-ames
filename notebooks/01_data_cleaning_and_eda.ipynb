# %%
#Importando bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carregando a base de dados de treino
url_test = 'https://raw.githubusercontent.com/diegobremer/predicting-house-prices-ames/main/data/raw/train.csv'
df_train = pd.read_csv(url_test)

#Ver as primeiras linhas da base de dados
print("--- Primeiras Linhas ---")
display(df_train.head())

#Ver as últimas linhas da base de dados
print("--- Últimas Linhas ---")
display(df_train.tail())

#Verificando o tamanho da base de dados
print("\n--- Tamanho da Base de Dados ---")
print(f"Linhas: {df_train.shape[0]} | Colunas: {df_train.shape[1]}")

#Verificando os tipos de dados
print("\n--- Tipos de Dados ---")
df_train.info()

#Verificando os valores ausentes
print("\n--- Valores Ausentes ---")
print(df_train.isnull().sum())
# Out:
# --- Primeiras Linhas ---
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    534  531363010           20        RL          80.0      9605   Pave
# 1    803  906203120           20        RL          90.0     14684   Pave
# 2    956  916176030           20        RL           NaN     14375   Pave
# 3    460  528180130          120        RL          48.0      6472   Pave
# 4    487  528290030           80        RL          61.0      9734   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       Reg          Lvl    AllPub     Corner        Gtl      SawyerW
# 1   NaN       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2   NaN       IR1          Lvl    NoSeWa    CulDSac        Gtl       Timber
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             7             6
# 1        Norm        Norm      1Fam      1Story             7             7
# 2        Norm        Norm      1Fam        SLvl             6             6
# 3        Norm        Norm    TwnhsE      1Story             9             5
# 4        RRAn        Norm      1Fam        SLvl             7             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        2007            2007      Gable   CompShg      VinylSd      VinylSd
# 1        1990            1991        Hip   CompShg      HdBoard      HdBoard
# 2        1958            1958      Gable   CompShg      HdBoard      HdBoard
# 3        2008            2008        Hip   CompShg      VinylSd      VinylSd
# 4        2004            2004      Gable   CompShg      VinylSd      VinylSd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0          NaN           0.0         Gd         TA      PConc        Gd
# 1      BrkFace         234.0         Gd         TA     CBlock        Gd
# 2      BrkFace         541.0         TA         TA     CBlock        TA
# 3      BrkFace         500.0         Ex         TA      PConc        Ex
# 4          NaN           0.0         Gd         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            Unf           0.0            Unf
# 1        TA            Mn            ALQ         485.0            BLQ
# 2        TA            No            GLQ         111.0            Rec
# 3        TA            No            Unf           0.0            Unf
# 4        TA            Mn            GLQ         241.0            Rec
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0       1218.0         1218.0    GasA         Ex           Y
# 1         177.0       1496.0         2158.0    GasA         Gd           Y
# 2         354.0        354.0          819.0    GasA         Gd           Y
# 3           0.0       1451.0         1451.0    GasA         Ex           Y
# 4         113.0         30.0          384.0    GasA         Ex           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr        1218           0                0         1218
# 1      SBrkr        2196           0                0         2196
# 2      FuseA        1344           0                0         1344
# 3      SBrkr        1456           0                0         1456
# 4      SBrkr         744         630                0         1374
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          1          1              3
# 1             0.0             0.0          2          0              3
# 2             0.0             1.0          1          0              3
# 3             0.0             0.0          2          0              2
# 4             0.0             0.0          2          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              7        Typ           1
# 2              1           Gd              7        Typ           1
# 3              1           Ex              6        Typ           1
# 4              1           Gd              7        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Detchd         2007.0           RFn          2.0
# 1           TA      Attchd         1990.0           RFn          3.0
# 2           Gd     Basment         1958.0           RFn          2.0
# 3           Gd      Attchd         2008.0           RFn          2.0
# 4          NaN     BuiltIn         2004.0           Fin          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        576.0          TA          TA           Y             0
# 1        701.0          TA          TA           Y            84
# 2        525.0          TA          TA           Y             0
# 3        539.0          TA          TA           Y           192
# 4        400.0          TA          TA           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0            178               0           0             0          0     NaN
# 1             70               0           0             0          0     NaN
# 2            118               0           0           233          0     NaN
# 3             42               0           0             0          0     NaN
# 4              0               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition  \
# 0   NaN          NaN         0        4     2009       WD          Normal
# 1   NaN          NaN         0        6     2009       WD          Normal
# 2   NaN          NaN         0        1     2009       COD        Abnorml
# 3   NaN          NaN         0        4     2009       WD          Normal
# 4   NaN          NaN         0        5     2009       WD          Normal
#
#    SalePrice
# 0     159000
# 1     271900
# 2     137500
# 3     248500
# 4     167000
# --- Últimas Linhas ---
#       Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 2192   2764  906420020           60        RL          80.0     10041   Pave
# 2193    906  909129090           50        RH          70.0      6300   Pave
# 2194   1097  528292060           60        RL          41.0     12460   Pave
# 2195    236  905426060           30        RL          85.0     10625   Pave
# 2196   1062  528142020           60        RL          74.0      8899   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 2192   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 2193  Pave       Reg          Lvl    AllPub     Corner        Gtl
# 2194   NaN       IR1          Lvl    AllPub        FR2        Gtl
# 2195   NaN       Reg          Lvl    AllPub     Corner        Gtl
# 2196   NaN       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 2192      SawyerW        Norm        Norm      1Fam      2Story             8
# 2193        SWISU        Norm        Norm      1Fam      1.5Fin             5
# 2194      Gilbert        RRAn        Norm      1Fam      2Story             7
# 2195      Edwards        Norm        Norm      1Fam      1Story             5
# 2196      NridgHt        Norm        Norm      1Fam      2Story             8
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 2192             5        1992            1992      Gable   CompShg
# 2193             4        1938            1950      Gable   CompShg
# 2194             5        1999            2000      Gable   CompShg
# 2195             5        1920            1950      Gable   CompShg
# 2196             5        2007            2007        Hip   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 2192      HdBoard      HdBoard          NaN           0.0         Gd
# 2193      MetalSd      MetalSd      BrkFace          88.0         TA
# 2194      VinylSd      VinylSd          NaN           0.0         Gd
# 2195      Wd Sdng      Wd Sdng          NaN           0.0         TA
# 2196      VinylSd      VinylSd        Stone         108.0         Ex
#
#      Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  \
# 2192         TA      PConc        Gd        TA            Mn            GLQ
# 2193         TA      PConc        TA        Fa            No            LwQ
# 2194         TA      PConc        Gd        TA            No            GLQ
# 2195         TA     BrkTil        TA        TA            No            ALQ
# 2196         TA      PConc        Gd        TA            Av            GLQ
#
#       BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  \
# 2192         789.0            Unf           0.0        119.0          908.0
# 2193         832.0            Unf           0.0          0.0          832.0
# 2194         870.0            Unf           0.0        167.0         1037.0
# 2195         108.0            Unf           0.0        350.0          458.0
# 2196          40.0            Unf           0.0        908.0          948.0
#
#      Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 2192    GasA         Ex           Y      SBrkr         927         988
# 2193    GasA         TA           Y      SBrkr         832         436
# 2194    GasA         Ex           Y      SBrkr        1037        1285
# 2195    GasA         Fa           N      SBrkr         835           0
# 2196    GasA         Ex           Y      SBrkr         948        1140
#
#       Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 2192                0         1915             1.0             0.0          2
# 2193                0         1268             0.0             0.0          1
# 2194                0         2322             0.0             0.0          2
# 2195                0          835             0.0             0.0          1
# 2196                0         2088             0.0             0.0          2
#
#       Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 2192          1              3              1           Gd              8
# 2193          1              3              1           TA              7
# 2194          1              4              1           TA              8
# 2195          0              2              1           TA              5
# 2196          1              4              1           Gd             10
#
#      Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt  \
# 2192        Typ           1           TA      Attchd         1992.0
# 2193        Typ           2           Gd     Basment         1938.0
# 2194        Typ           1           TA     BuiltIn         1999.0
# 2195        Typ           0          NaN     Basment         1920.0
# 2196        Typ           1           Gd     BuiltIn         2007.0
#
#      Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond  \
# 2192           Fin          2.0        506.0          TA          TA
# 2193           Unf          1.0        250.0          TA          TA
# 2194           Fin          2.0        400.0          TA          TA
# 2195           Unf          1.0        366.0          Fa          TA
# 2196           Fin          3.0        656.0          TA          TA
#
#      Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# 2192           Y           120            150               0           0
# 2193           Y             0              0              55           0
# 2194           Y           144             44               0           0
# 2195           Y             0              0              77           0
# 2196           Y           100             24               0           0
#
#       Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  Mo Sold  \
# 2192             0          0     NaN   NaN          NaN         0        2
# 2193             0          0     NaN   NaN          NaN         0        7
# 2194             0          0     NaN   NaN          NaN         0        5
# 2195             0          0     NaN   NaN         Shed       400        5
# 2196             0          0     NaN   NaN          NaN         0        6
#
#       Yr Sold Sale Type Sale Condition  SalePrice
# 2192     2006       WD         Abnorml     220000
# 2193     2009       WD         Abnorml     160000
# 2194     2008       WD          Normal     225000
# 2195     2010       COD        Abnorml      83000
# 2196     2008       WD          Normal     250000
# --- Tamanho da Base de Dados ---
# Linhas: 2197 | Colunas: 82
#
# --- Tipos de Dados ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2197 entries, 0 to 2196
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2197 non-null   int64
#  1   PID              2197 non-null   int64
#  2   MS SubClass      2197 non-null   int64
#  3   MS Zoning        2197 non-null   object
#  4   Lot Frontage     1835 non-null   float64
#  5   Lot Area         2197 non-null   int64
#  6   Street           2197 non-null   object
#  7   Alley            143 non-null    object
#  8   Lot Shape        2197 non-null   object
#  9   Land Contour     2197 non-null   object
#  10  Utilities        2197 non-null   object
#  11  Lot Config       2197 non-null   object
#  12  Land Slope       2197 non-null   object
#  13  Neighborhood     2197 non-null   object
#  14  Condition 1      2197 non-null   object
#  15  Condition 2      2197 non-null   object
#  16  Bldg Type        2197 non-null   object
#  17  House Style      2197 non-null   object
#  18  Overall Qual     2197 non-null   int64
#  19  Overall Cond     2197 non-null   int64
#  20  Year Built       2197 non-null   int64
#  21  Year Remod/Add   2197 non-null   int64
#  22  Roof Style       2197 non-null   object
#  23  Roof Matl        2197 non-null   object
#  24  Exterior 1st     2197 non-null   object
#  25  Exterior 2nd     2197 non-null   object
#  26  Mas Vnr Type     868 non-null    object
#  27  Mas Vnr Area     2175 non-null   float64
#  28  Exter Qual       2197 non-null   object
#  29  Exter Cond       2197 non-null   object
#  30  Foundation       2197 non-null   object
#  31  Bsmt Qual        2130 non-null   object
#  32  Bsmt Cond        2130 non-null   object
#  33  Bsmt Exposure    2128 non-null   object
#  34  BsmtFin Type 1   2130 non-null   object
#  35  BsmtFin SF 1     2196 non-null   float64
#  36  BsmtFin Type 2   2129 non-null   object
#  37  BsmtFin SF 2     2196 non-null   float64
#  38  Bsmt Unf SF      2196 non-null   float64
#  39  Total Bsmt SF    2196 non-null   float64
#  40  Heating          2197 non-null   object
#  41  Heating QC       2197 non-null   object
#  42  Central Air      2197 non-null   object
#  43  Electrical       2196 non-null   object
#  44  1st Flr SF       2197 non-null   int64
#  45  2nd Flr SF       2197 non-null   int64
#  46  Low Qual Fin SF  2197 non-null   int64
#  47  Gr Liv Area      2197 non-null   int64
#  48  Bsmt Full Bath   2196 non-null   float64
#  49  Bsmt Half Bath   2196 non-null   float64
#  50  Full Bath        2197 non-null   int64
#  51  Half Bath        2197 non-null   int64
#  52  Bedroom AbvGr    2197 non-null   int64
#  53  Kitchen AbvGr    2197 non-null   int64
#  54  Kitchen Qual     2197 non-null   object
#  55  TotRms AbvGrd    2197 non-null   int64
#  56  Functional       2197 non-null   object
#  57  Fireplaces       2197 non-null   int64
#  58  Fireplace Qu     1131 non-null   object
#  59  Garage Type      2077 non-null   object
#  60  Garage Yr Blt    2075 non-null   float64
#  61  Garage Finish    2075 non-null   object
#  62  Garage Cars      2196 non-null   float64
#  63  Garage Area      2196 non-null   float64
#  64  Garage Qual      2075 non-null   object
#  65  Garage Cond      2075 non-null   object
#  66  Paved Drive      2197 non-null   object
#  67  Wood Deck SF     2197 non-null   int64
#  68  Open Porch SF    2197 non-null   int64
#  69  Enclosed Porch   2197 non-null   int64
#  70  3Ssn Porch       2197 non-null   int64
#  71  Screen Porch     2197 non-null   int64
#  72  Pool Area        2197 non-null   int64
#  73  Pool QC          12 non-null     object
#  74  Fence            419 non-null    object
#  75  Misc Feature     80 non-null     object
#  76  Misc Val         2197 non-null   int64
#  77  Mo Sold          2197 non-null   int64
#  78  Yr Sold          2197 non-null   int64
#  79  Sale Type        2197 non-null   object
#  80  Sale Condition   2197 non-null   object
#  81  SalePrice        2197 non-null   int64
# dtypes: float64(11), int64(28), object(43)
# memory usage: 1.4+ MB
#
# --- Valores Ausentes ---
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      362
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
# Calcular a quantidade de valores nulos por coluna
valores_nulos = df_train.isnull().sum()

# Filtrar apenas as colunas que possuem pelo menos 1 valor nulo
colunas_com_nulos = valores_nulos[valores_nulos > 0].sort_values(ascending=False)

# Calcular a porcentagem de valores nulos para ficar mais visual
porcentagem_nulos = (colunas_com_nulos / len(df_train)) * 100

# Juntar os dois dados em um DataFrame para analisar melhor
relatorio_nulos = pd.DataFrame({
    'Total de Nulos': colunas_com_nulos,
    'Porcentagem (%)': porcentagem_nulos
})

print("--- Colunas com Valores Ausentes no Treino ---")
display(relatorio_nulos)
# Out:
# --- Colunas com Valores Ausentes no Treino ---
#                 Total de Nulos  Porcentagem (%)
# Pool QC                   2185        99.453801
# Misc Feature              2117        96.358671
# Alley                     2054        93.491124
# Fence                     1778        80.928539
# Mas Vnr Type              1329        60.491579
# Fireplace Qu              1066        48.520710
# Lot Frontage               362        16.477014
# Garage Qual                122         5.553027
# Garage Cond                122         5.553027
# Garage Yr Blt              122         5.553027
# Garage Finish              122         5.553027
# Garage Type                120         5.461994
# Bsmt Exposure               69         3.140646
# BsmtFin Type 2              68         3.095130
# Bsmt Cond                   67         3.049613
# Bsmt Qual                   67         3.049613
# BsmtFin Type 1              67         3.049613
# Mas Vnr Area                22         1.001365
# BsmtFin SF 1                 1         0.045517
# BsmtFin SF 2                 1         0.045517
# Bsmt Half Bath               1         0.045517
# Electrical                   1         0.045517
# Bsmt Full Bath               1         0.045517
# Bsmt Unf SF                  1         0.045517
# Total Bsmt SF                1         0.045517
# Garage Area                  1         0.045517
# Garage Cars                  1         0.045517

# %%
#Criando uma copia do banco de dados para preservar antes do tratamento
df_clean = df_train.copy()

# %%
#Lista de colunas categoricas onde NaN significa "Nao tem" (none)
colunas_para_none = [
    'Pool QC', 'Misc Feature', 'Alley', 'Fence', 'Fireplace Qu',
    'Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond',
    'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2',
    'Mas Vnr Type'
]

#Substituindo NaN por "None"
for coluna in colunas_para_none:
    df_clean[coluna] = df_clean[coluna].fillna("None")

# %%
#Lista de colunas numéricas onde NaN significa 0 ( area e quantidade )
colunas_para_zero = [
    'Garage Cars', 'Garage Area', 'Mas Vnr Area',
    'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
    'Bsmt Full Bath', 'Bsmt Half Bath'
]
#Substituindo NaN por 0 nessas colunas
for coluna in colunas_para_zero:
    df_clean[coluna] = df_clean[coluna].fillna(0)

# %%
#Verificando como ficou apos tratamento
print("Tratamento concluido! Restam nulos nas colunas tratadas?")
print(df_clean[colunas_para_none + colunas_para_zero].isnull().sum().sum())
# Out:
# Tratamento concluido! Restam nulos nas colunas tratadas?
# 0

# %%
# Mudar a configuração para exibir até 100 colunas sem omitir nenhuma
pd.set_option('display.max_columns', 100)
print(df_clean.head())
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    534  531363010           20        RL          80.0      9605   Pave
# 1    803  906203120           20        RL          90.0     14684   Pave
# 2    956  916176030           20        RL           NaN     14375   Pave
# 3    460  528180130          120        RL          48.0      6472   Pave
# 4    487  528290030           80        RL          61.0      9734   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  None       Reg          Lvl    AllPub     Corner        Gtl      SawyerW
# 1  None       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2  None       IR1          Lvl    NoSeWa    CulDSac        Gtl       Timber
# 3  None       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 4  None       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             7             6
# 1        Norm        Norm      1Fam      1Story             7             7
# 2        Norm        Norm      1Fam        SLvl             6             6
# 3        Norm        Norm    TwnhsE      1Story             9             5
# 4        RRAn        Norm      1Fam        SLvl             7             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        2007            2007      Gable   CompShg      VinylSd      VinylSd
# 1        1990            1991        Hip   CompShg      HdBoard      HdBoard
# 2        1958            1958      Gable   CompShg      HdBoard      HdBoard
# 3        2008            2008        Hip   CompShg      VinylSd      VinylSd
# 4        2004            2004      Gable   CompShg      VinylSd      VinylSd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         None           0.0         Gd         TA      PConc        Gd
# 1      BrkFace         234.0         Gd         TA     CBlock        Gd
# 2      BrkFace         541.0         TA         TA     CBlock        TA
# 3      BrkFace         500.0         Ex         TA      PConc        Ex
# 4         None           0.0         Gd         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            Unf           0.0            Unf
# 1        TA            Mn            ALQ         485.0            BLQ
# 2        TA            No            GLQ         111.0            Rec
# 3        TA            No            Unf           0.0            Unf
# 4        TA            Mn            GLQ         241.0            Rec
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0       1218.0         1218.0    GasA         Ex           Y
# 1         177.0       1496.0         2158.0    GasA         Gd           Y
# 2         354.0        354.0          819.0    GasA         Gd           Y
# 3           0.0       1451.0         1451.0    GasA         Ex           Y
# 4         113.0         30.0          384.0    GasA         Ex           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr        1218           0                0         1218
# 1      SBrkr        2196           0                0         2196
# 2      FuseA        1344           0                0         1344
# 3      SBrkr        1456           0                0         1456
# 4      SBrkr         744         630                0         1374
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          1          1              3
# 1             0.0             0.0          2          0              3
# 2             0.0             1.0          1          0              3
# 3             0.0             0.0          2          0              2
# 4             0.0             0.0          2          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              7        Typ           1
# 2              1           Gd              7        Typ           1
# 3              1           Ex              6        Typ           1
# 4              1           Gd              7        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0         None      Detchd         2007.0           RFn          2.0
# 1           TA      Attchd         1990.0           RFn          3.0
# 2           Gd     Basment         1958.0           RFn          2.0
# 3           Gd      Attchd         2008.0           RFn          2.0
# 4         None     BuiltIn         2004.0           Fin          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        576.0          TA          TA           Y             0
# 1        701.0          TA          TA           Y            84
# 2        525.0          TA          TA           Y             0
# 3        539.0          TA          TA           Y           192
# 4        400.0          TA          TA           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0            178               0           0             0          0    None
# 1             70               0           0             0          0    None
# 2            118               0           0           233          0    None
# 3             42               0           0             0          0    None
# 4              0               0           0             0          0    None
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition  \
# 0  None         None         0        4     2009       WD          Normal
# 1  None         None         0        6     2009       WD          Normal
# 2  None         None         0        1     2009       COD        Abnorml
# 3  None         None         0        4     2009       WD          Normal
# 4  None         None         0        5     2009       WD          Normal
#
#    SalePrice
# 0     159000
# 1     271900
# 2     137500
# 3     248500
# 4     167000

# %%
#Verificando valores Nulos apos primeiro tratamento
valores_nulos = df_clean.isnull().sum()

# Filtrar apenas as colunas que possuem pelo menos 1 valor nulo
colunas_com_nulos = valores_nulos[valores_nulos > 0].sort_values(ascending=False)

# Calcular a porcentagem de valores nulos para ficar mais visual
porcentagem_nulos = (colunas_com_nulos / len(df_clean)) * 100

# Juntar os dois dados em um DataFrame para analisar melhor
relatorio_nulos = pd.DataFrame({
    'Total de Nulos': colunas_com_nulos,
    'Porcentagem (%)': porcentagem_nulos
})

print("--- Colunas com Valores Ausentes no Treino ---")
display(relatorio_nulos)
# Out:
# --- Colunas com Valores Ausentes no Treino ---
#                Total de Nulos  Porcentagem (%)
# Lot Frontage              362        16.477014
# Garage Yr Blt             122         5.553027
# Electrical                  1         0.045517

# %%
# 1. Tratar 'Electrical': Preencher com a Moda (o valor mais comum)
moda_eletrico = df_clean['Electrical'].mode()[0]
df_clean['Electrical'] = df_clean['Electrical'].fillna(moda_eletrico)

# 2. Tratar 'Garage Yr Blt': Como a garagem não existe, vamos usar a mediana geral dos anos
mediana_garagem = df_clean['Garage Yr Blt'].median()
df_clean['Garage Yr Blt'] = df_clean['Garage Yr Blt'].fillna(mediana_garagem)

# 3. Tratar 'Lot Frontage': Preencher com a mediana da frente do terreno de cada bairro
df_clean['Lot Frontage'] = df_clean.groupby('Neighborhood')['Lot Frontage'].transform(lambda x: x.fillna(x.median()))

# --- VALIDAÇÃO FINAL ---
# Rodar novamente o verificador para cravar o ZERO absoluto no dataset inteiro
print("Quantidade total de nulos restantes no dataset inteiro:")
print(df_clean.isnull().sum().sum())
# Out:
# Quantidade total de nulos restantes no dataset inteiro:
# 2

# %%
# 1. Descobrir qual coluna ainda tem esses 2 nulos
nulos_restantes = df_clean.isnull().sum()
print("--- Coluna(s) culpada(s) ---")
print(nulos_restantes[nulos_restantes > 0])

# 2. Ver as linhas exatas onde isso aconteceu para entender o motivo
linhas_com_nulo = df_clean[df_clean.isnull().any(axis=1)]
print("\n--- Linhas afetadas ---")
display(linhas_com_nulo[['Neighborhood', 'Lot Frontage']])
# Out:
# --- Coluna(s) culpada(s) ---
# Lot Frontage    2
# dtype: int64
#
# --- Linhas afetadas ---
#      Neighborhood  Lot Frontage
# 198       Landmrk           NaN
# 1061      GrnHill           NaN

# %%
# Substituir os nulos restantes pela mediana global da coluna
df_clean['Lot Frontage'] = df_clean['Lot Frontage'].fillna(df_clean['Lot Frontage'].median())

# Salvar o arquivo final com o ZERO absoluto cravado
df_clean.to_csv('AmesHousing_train_clean.csv', index=False)

print("--- Verificação Final de Nulos no Dataset Inteiro ---")
print(f"Total de NaNs restantes: {df_clean.isnull().sum().sum()}")
# Out:
# --- Verificação Final de Nulos no Dataset Inteiro ---
# Total de NaNs restantes: 0
